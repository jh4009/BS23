# %%
import requests
from bs4 import BeautifulSoup
import os

# %%
URL = 'https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36"}
page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

# %%
soup2
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->
# <!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->
# <!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="a-no-js" lang="en-us">
# <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title dir="ltr">
#    Amazon.com
#   </title>
# <meta content="width=device-width" name="viewport"/>
# <link href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css" rel="stylesheet"/>
# <script>
#    if (true === true) {
#     var ue_t0 = (+ new Date()),
#         ue_csm = window,
#         ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },
# ...

# %%
id="productTitle"

# %%
title_element = soup2.find(id="productTitle")
if title_element:
    title = title_element.get_text()
    print(title)
else:
    print("Product title not found.")
# Out:
# Product title not found.

# %%
links = soup.find_all("img")

# %%
links
# Out:
# [<img alt="Amazon.com" id="b" src="https://images-na.ssl-images-amazon.com/images/G/01/error/logo._TTD_.png"/>,
#  <img alt="Sorry! Something went wrong on our end. Please go back and try again or go to Amazon's home page." src="https://images-na.ssl-images-amazon.com/images/G/01/error/500_503.png"/>,
#  <img alt="Dogs of Amazon" id="d"/>]

# %%
if not os.path.exists('nwt_images'):
    os.makedirs('nwt_images')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# ...

# %%
iframe1 = soup.find_all('a')

# %%
iframe1
# Out:
# [<a aria-label="Prothom alo" class="VDuHf sGZHG" href="/"><h2 class="desktop-logo kWicl"><svg class="_22xN6 _0OvNG" preserveaspectratio="none"><use href="/prothomalo/assets/sprite-2147d6c36409557ea33408e957be2b6a.svg#palo-english"></use></svg></h2></a>,
#  <a aria-label="Prothom alo search" class="search _5ndd-" href="/search" target="_self"><div class="TDAsr"><svg class="DSRqc" enable-background="new 0 0 32 32" viewbox="0 0 32 32" xml:space="preserve" xmlns="http://www.w3.org/2000/svg"><path d="M25.2,27.067L17.733,19.6c-0.667,0.533-1.433,0.956-2.3,1.267c-0.867,0.311-1.789,0.467-2.767,0.467
#  c-2.422,0-4.472-0.839-6.15-2.517C4.839,17.139,4,15.089,4,12.667c0-2.422,0.839-4.472,2.517-6.15C8.194,4.839,10.244,4,12.667,4
#  c2.422,0,4.472,0.839,6.15,2.517c1.678,1.678,2.517,3.728,2.517,6.15c0,0.978-0.156,1.9-0.467,2.767
#  c-0.311,0.867-0.733,1.633-1.267,2.3l7.5,7.5c0.244,0.245,0.367,0.545,0.367,0.9c0,0.356-0.133,0.667-0.4,0.933
# ...

# %%
for source in iframe1:
    #name = source['alt']
    link = source['src']

    print(link)
# Out:
# https://www.googletagmanager.com/ns.html?id=GTM-P528B3&gtm_auth=tfAzqo1rYDLgYhmTnSjPqw&gtm_preview=env-130&gtm_cookies_win=x

# %%
link
# Out:
# 'https://www.googletagmanager.com/ns.html?id=GTM-P528B3&gtm_auth=tfAzqo1rYDLgYhmTnSjPqw&gtm_preview=env-130&gtm_cookies_win=x'

# %% [markdown]
# #single Image

# %%
img_url = "link"

img_data = requests.get(img_url).content
with open("downloaded_image.mp4", "wb") as f:
    f.write(img_data)

print("Image downloaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[26], line 3
#       1 img_url = "link"
# ----> 3 img_data = requests.get(img_url).content
#       4 with open("downloaded_image.mp4", "wb") as f:
#       5     f.write(img_data)
#
# File c:\Users\jahid\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\jahid\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
# ...

# %%
for i, img in enumerate(img1):
    img_url = img.get('src')
    if img_url and img_url.startswith("http"):
        img_data = requests.get(img_url).content
        with open(f"bs23_images/image_{i}.jpg", 'wb') as f:
            f.write(img_data)
        print(f"Downloaded: image_{i}.jpg")
# Out:
# Downloaded: image_0.jpg
# Downloaded: image_1.jpg
# Downloaded: image_2.jpg
# Downloaded: image_3.jpg
# Downloaded: image_5.jpg
# Downloaded: image_7.jpg
# Downloaded: image_9.jpg
# Downloaded: image_11.jpg
# Downloaded: image_13.jpg
# Downloaded: image_15.jpg
# Downloaded: image_17.jpg
# Downloaded: image_19.jpg
# Downloaded: image_21.jpg
# Downloaded: image_23.jpg
# Downloaded: image_25.jpg
# Downloaded: image_27.jpg
# Downloaded: image_29.jpg
# Downloaded: image_31.jpg
# Downloaded: image_33.jpg
# Downloaded: image_35.jpg
# Downloaded: image_37.jpg
# Downloaded: image_39.jpg
# Downloaded: image_41.jpg
# Downloaded: image_43.jpg
# Downloaded: image_45.jpg
# Downloaded: image_47.jpg
# Downloaded: image_49.jpg
# Downloaded: image_51.jpg
# Downloaded: image_53.jpg
# Downloaded: image_55.jpg
# Downloaded: image_57.jpg
# Downloaded: image_59.jpg
# Downloaded: image_61.jpg
# Downloaded: image_63.jpg
# Downloaded: image_65.jpg
# Downloaded: image_67.jpg
# Downloaded: image_69.jpg
# ...

# %%
import requests

API_URL = "http://172.16.227.1:8000/upload/"
file_path = "downloaded_image.jpg"

# Open the file in binary mode
with open(file_path, "rb") as file:
    files = {"file": (file_path, file, "image/jpeg")}  # Adjust MIME type if needed
    
    try:
        response = requests.post(API_URL, files=files, timeout=10)  # Added timeout
        response.raise_for_status()  # Raises HTTP errors (e.g., 400, 500)
        
        # Handle non-JSON responses gracefully
        try:
            print("Upload successful:", response.json())
        except requests.exceptions.JSONDecodeError:
            print("Upload successful, but response is not JSON:", response.text)

    except requests.exceptions.RequestException as e:
        print(f"Error uploading file: {e}")
# Out:
# Error uploading file: HTTPConnectionPool(host='172.16.227.1', port=8000): Max retries exceeded with url: /upload/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x000001EE695FF680>, 'Connection to 172.16.227.1 timed out. (connect timeout=10)'))
